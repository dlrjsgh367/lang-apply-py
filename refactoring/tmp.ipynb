# %%
from typing import List, Tuple

import numpy as np
import pandas as pd
from tmp import process_korean_lines

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
file_path = r"C:\Users\HAMA\workspace\tmp\lang-apply-py\src\features\mypage\screens\document_jobseeker_screen.dart"
extracted_results = process_korean_lines(file_path)

# %%
columns = ['Key', 'Description', 'en', 'ko', 'origin']
df = pd.DataFrame(columns=columns)

# %%
df['ko'] = [x['korean_phrases'] for x in extracted_results]
df['origin'] = [x['original_line'] for x in extracted_results]

df = df.replace({np.nan: None})

# %%
# 정규식 조건 설정
exclude_patterns = [r'\$\{', r'\{']  # `${` or `{` pattern
pattern = '|'.join(exclude_patterns)  # Join patterns with OR

# 필터링 조건 적용
df_manual = df[df['origin'].str.contains(pattern, regex=True)]  # 조건에 맞는 행 추출
df_automatic = df[~df['origin'].str.contains(pattern, regex=True)]  # 조건에 맞지 않는 행 추출

# %%
df_manual
# Out:
#     Key Description    en   ko  \
# 0  None        None  None  )}년
# 1  None        None  None  )}월
# 2  None        None  None  )}일
# 3  None        None  None  )}년
# 4  None        None  None  )}월
# 5  None        None  None  )}일
#
#                                                                   origin
# 0        formattedDate = '${dateTime.year.toString().padLeft(4, '0')}년 '
# 1                       '${dateTime.month.toString().padLeft(2, '0')}월 '
# 2                         '${dateTime.day.toString().padLeft(2, '0')}일';
# 3        formattedDate = '${dateTime.year.toString().padLeft(4, '0')}년 '
# 4                       '${dateTime.month.toString().padLeft(2, '0')}월 '
# 5                         '${dateTime.day.toString().padLeft(2, '0')}일';

# %%
df_automatic
# Out:
#      Key Description    en              ko  \
# 6   None        None  None         계약서/사직서
# 7   None        None  None             계약서
# 8   None        None  None             사직서
# 9   None        None  None  작성된 계약서가 없습니다.
# 10  None        None  None  작성된 사직서가 없습니다.
#
#                                                                   origin
# 6                                                      title: '계약서/사직서',
# 7                                     tabTitleArr: const ['계약서', '사직서'],
# 8                                     tabTitleArr: const ['계약서', '사직서'],
# 9                           : const CommonEmpty(text: '작성된 계약서가 없습니다.'),
# 10                          : const CommonEmpty(text: '작성된 사직서가 없습니다.'),

# %%
def split_extracted_results(parsed_data) -> Tuple[List]:
    # Default dataframe structure
    df_columns = ['Key', 'Description', 'en', 'ko', 'origin']
    results_df = pd.DataFrame(columns=df_columns)
    
    # Assign values
    results_df['ko'] = [x['korean_phrases'] for x in parsed_data]
    results_df['origin'] = [x['original_line'] for x in parsed_data]
    
    # Replace NaN with None
    results_df = results_df.replace({np.nan: None})
    
    # Patterns to exclude
    exclude_patterns = [r'\$\{', r'\{']  # `${` or `{` pattern
    exclude_pattern_regex = '|'.join(exclude_patterns)  # Join patterns with OR
    
    # Split into manual and automatic dataframes
    manual_entries_df = results_df[results_df['origin'].str.contains(exclude_pattern_regex, regex=True)]
    automatic_entries_df = results_df[~results_df['origin'].str.contains(exclude_pattern_regex, regex=True)]
    
    # Convert to lists
    manual_entries_list = manual_entries_df.values.tolist()
    automatic_entries_list = automatic_entries_df.values.tolist()
    
    return manual_entries_list, automatic_entries_list

# %%
from task import KoreanTextPipeline


path_dir = r"C:\Users\HAMA\workspace\tmp\lang-apply-py\src\features\mypage\screens"

pipeline = KoreanTextPipeline(path_dir)
pipeline.process_files()

# %%
for x in sorted(pipeline.data_automatic):
    print(x)
# Out:
# [None, None, None, '$origin 전체', "return '$origin 전체';"]
# [None, None, None, '(가입 30일 이후 지급, 단 초대 받은 회원이 탈퇴, 재가입 할 경우 지급 안됨)', "'(가입 30일 이후 지급, 단 초대 받은 회원이 탈퇴, 재가입 할 경우 지급 안됨)',"]
# [None, None, None, '- 추가 금액 충전은 고객센터 (help@chodan.co.kr, 연락 받을 전화번호도 기재)로 문의 주세요. n- 유료 충전한 초단코인은 유효기간이 1년입니다. 유효기간이 지나면 미사용된 초단코인은 소멸합니다. (무료지급 및 보너스 초단코인 유효기간 45일) n- 유료 충전한 초단코인은 미사용시 구매후 7일이내 청약을 철회할 수 있습니다. (세부내용은 기업회원이용약관 참고) n- 단 구매한 초단코인 또는 보너스로 추가 지급된 초단코인을 이미 사용했다면 청약철회가 불가능합니다.', "'- 추가 금액 충전은 고객센터 (help@chodan.co.kr, 연락 받을 전화번호도 기재)로 문의 주세요.\\n- 유료 충전한 초단코인은 유효기간이 1년입니다. 유효기간이 지나면 미사용된 초단코인은 소멸합니다. (무료지급 및 보너스 초단코인 유효기간 45일)\\n- 유료 충전한 초단코인은 미사용시 구매후 7일이내 청약을 철회할 수 있습니다. (세부내용은 기업회원이용약관 참고)\\n- 단 구매한 초단코인 또는 보너스로 추가 지급된 초단코인을 이미 사용했다면 청약철회가 불가능합니다.',"]
# [None, None, None, '---답변입니다.', '//           const Text("---답변입니다."),']
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '0 초코', "? '0 초코'"]
# [None, None, None, '30일 이내 소멸 초단코인', "'30일 이내 소멸 초단코인',"]
# [None, None, None, 'yyyy년 MM월 dd일', "DateFormat('yyyy년 MM월 dd일').format(DateTime.now()),"]
# [None, None, None, '가 포함되어 노무 상담 등록이 불가능합니다.', 'alertContent: "금칙어 \'" + keyword + "\'가 포함되어 노무 상담 등록이 불가능합니다.",']
# [None, None, None, '가 포함되어 노무 상담 수정이 불가능합니다.', 'alertContent: "금칙어 \'" + keyword + "\'가 포함되어 노무 상담 수정이 불가능합니다.",']
# [None, None, None, '게시글 작성에 실패하였습니다.', "showDefaultToast('게시글 작성에 실패하였습니다.');"]
# [None, None, None, '게재 중 공고', "'게재 중 공고',"]
# [None, None, None, '결제 초코', "'결제 초코',"]
# [None, None, None, '결제 초코', "'결제 초코',"]
# [None, None, None, '결제 취소하였습니다.', "showDefaultToast('결제 취소하였습니다.');"]
# [None, None, None, '결제 취소하였습니다.', "showDefaultToast('결제 취소하였습니다.');"]
# [None, None, None, '결제가 완료되었습니다..', "showDefaultToast('결제가 완료되었습니다..');"]
# [None, None, None, '결제에 실패했습니다.', "showErrorAlert(context, '알림', '결제에 실패했습니다.');"]
# [None, None, None, '경력', "title: '경력',"]
# [None, None, None, '경력', "title: '경력',"]
# [None, None, None, '경력을 요구하는 업무 지원에 훨씬 유리해요!', ": '경력을 요구하는 업무 지원에 훨씬 유리해요!',"]
# [None, None, None, '경력을 요구하는 업무 지원에 훨씬 유리해요!', ": '경력을 요구하는 업무 지원에 훨씬 유리해요!',"]
# [None, None, None, '계약서', "tabTitleArr: const ['계약서', '사직서'],"]
# [None, None, None, '계약서', "tabTitleArr: const ['계약서', '사직서'],"]
# [None, None, None, '계약서/사직서', "text: '계약서/사직서',"]
# [None, None, None, '계약서/사직서', "text: '계약서/사직서',"]
# [None, None, None, '계약서/사직서', "title: '계약서/사직서',"]
# [None, None, None, '계약서/사직서', "title: '계약서/사직서',"]
# [None, None, None, '공고 관리', "text: '공고 관리',"]
# [None, None, None, '공유가 완료되었습니다.', 'showDefaultToast("공유가 완료되었습니다.");']
# [None, None, None, '관심 기업 추가', "return '관심 기업 추가';"]
# [None, None, None, '관심 기업이 없습니다.', "text: activeTab == 0 ? '관심 기업이 없습니다.' : '차단 기업이 없습니다.')"]
# [None, None, None, '관심 인재 추가', "return '관심 인재 추가';"]
# [None, None, None, '관심/차단기업', "title: '관심/차단기업',"]
# [None, None, None, '관심/차단인재', "title: '관심/차단인재',"]
# [None, None, None, '관심기업', "'관심기업',"]
# [None, None, None, '관심기업', "tabTitleArr: const ['관심기업', '차단기업'],"]
# [None, None, None, '관심기업에서 삭제했어요!', "showDefaultToast('관심기업에서 삭제했어요!');"]
# [None, None, None, '관심기업으로 저장했어요!', "showDefaultToast('관심기업으로 저장했어요!');"]
# [None, None, None, '관심인재', "'관심인재',"]
# [None, None, None, '관심인재', "tabTitleArr: const ['관심인재', '차단인재'],"]
# [None, None, None, '관심인재가 없습니다.', "text: activeTab == 0 ? '관심인재가 없습니다.' : '차단인재가 없습니다.')"]
# [None, None, None, '관심인재로 저장했어요!', "showDefaultToast('관심인재로 저장했어요!');"]
# [None, None, None, '관심인재로 저장했어요!', "showDefaultToast('관심인재로 저장했어요!');"]
# [None, None, None, '관심인재에서 삭제에 실패하였습니다.', "showDefaultToast('관심인재에서 삭제에 실패하였습니다.');"]
# [None, None, None, '관심인재에서 삭제했어요!', "showDefaultToast('관심인재에서 삭제했어요!');"]
# [None, None, None, '관심인재에서 삭제했어요!', "showDefaultToast('관심인재에서 삭제했어요!');"]
# [None, None, None, '글자확대', "'글자확대',"]
# [None, None, None, '금칙어', 'alertContent: "금칙어 \'" + keyword + "\'가 포함되어 노무 상담 등록이 불가능합니다.",']
# [None, None, None, '금칙어', 'alertContent: "금칙어 \'" + keyword + "\'가 포함되어 노무 상담 수정이 불가능합니다.",']
# [None, None, None, '금칙어가 감지되었어요.', "showDefaultToast('금칙어가 감지되었어요.');"]
# [None, None, None, '금칙어가 감지되었어요.', "showDefaultToast('금칙어가 감지되었어요.');"]
# [None, None, None, '기업 정보 등록', "return '기업 정보 등록';"]
# [None, None, None, '기업명', "'기업명',"]
# [None, None, None, '기업정보 수정', "text: '기업정보 수정',"]
# [None, None, None, '기타 설정', "TitleMenu(title: '기타 설정'),"]
# [None, None, None, '긴급구인', "'긴급구인',"]
# [None, None, None, '나의 초단 코인', "title: '나의 초단 코인',"]
# [None, None, None, '나의 활동 포인트', "'나의 활동 포인트',"]
# [None, None, None, '내 상담 내역', '"내 상담 내역",']
# [None, None, None, '내 프로필 보기', "title: '내 프로필 보기',"]
# [None, None, None, '노동관계 분야 전반에 대한 사항을 분석하여 n합리적인 개선방안을 제시해드려요.', "'노동관계 분야 전반에 대한 사항을 분석하여\\n합리적인 개선방안을 제시해드려요.',"]
# [None, None, None, '노무 상담 글쓰기', "return '노무 상담 글쓰기';"]
# [None, None, None, '노무 상담 하기', "text: '노무 상담 하기',"]
# [None, None, None, '노무 상담 하기', "text: '노무 상담 하기',"]
# [None, None, None, '노무 상담 하기', "title: '노무 상담 하기',"]
# [None, None, None, '노출', "'노출',"]
# [None, None, None, '닫기', "alertCancel: '닫기',"]
# [None, None, None, '답변 대기중', "'답변 대기중',"]
# [None, None, None, '답변완료', "'답변완료',"]
# [None, None, None, '대표', "'대표',"]
# [None, None, None, '대표 프로필 변경', "alertTitle: '대표 프로필 변경',"]
# [None, None, None, '대표 프로필 변경', "alertTitle: '대표 프로필 변경',"]
# [None, None, None, '대표 프로필은 1개만 설정 가능해요. n기존 대표 프로필을 현재 프로필로 변경 하시겠어요?', "alertContent: '대표 프로필은 1개만 설정 가능해요.\\n기존 대표 프로필을 현재 프로필로 변경 하시겠어요?',"]
# [None, None, None, '대표 프로필은 1개만 설정 가능해요. n기존 대표 프로필을 현재 프로필로 변경 하시겠어요?', "alertContent: '대표 프로필은 1개만 설정 가능해요.\\n기존 대표 프로필을 현재 프로필로 변경 하시겠어요?',"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터 통신에 실패하였습니다.', "showDefaultToast('데이터 통신에 실패하였습니다.');"]
# [None, None, None, '데이터가 없습니다.', ": const CommonEmpty(text: '데이터가 없습니다.'))"]
# [None, None, None, '데이터가 없습니다.', ": const CommonEmpty(text: '데이터가 없습니다.'),"]
# [None, None, None, '데이터가 없습니다.', "text: '데이터가 없습니다.',"]
# [None, None, None, '데이터가 없습니다.', "text: '데이터가 없습니다.',"]
# [None, None, None, '등록되었습니다.', "alertContent: '등록되었습니다.',"]
# [None, None, None, '등록되었습니다.', "alertContent: '등록되었습니다.',"]
# [None, None, None, '등록된 답변이 없습니다.', "'등록된 답변이 없습니다.',"]
# [None, None, None, '등록된 답변이 없습니다.', ": '등록된 답변이 없습니다.',"]
# [None, None, None, '등록된 프로필이 없어요.', "child: const CommonEmpty(text: '등록된 프로필이 없어요.'),"]
# [None, None, None, '등록에 실패하였습니다.', "showDefaultToast('등록에 실패하였습니다.');"]
# [None, None, None, '등록하기', "text: '등록하기',"]
# [None, None, None, '로 설정하시겠습니까?', '"로 설정하시겠습니까?",']
# [None, None, None, '로그아웃', "alertConfirm: '로그아웃',"]
# [None, None, None, '로그아웃', "text: '로그아웃',"]
# [None, None, None, '로그아웃 시 이 계정에 대한 모든 알림을 받을 수 없어요.', "alertContent: '로그아웃 시 이 계정에 대한 모든 알림을 받을 수 없어요.',"]
# [None, None, None, '로그인', "return '로그인';"]
# [None, None, None, '로그인', "return '로그인';"]
# [None, None, None, '마이페이지', "tabTitleArr: ['마이페이지', '설정'],"]
# [None, None, None, '마이페이지', "tabTitleArr: const ['마이페이지', '설정'],"]
# [None, None, None, '문의내용을 입력해주세요.', "hintText: '문의내용을 입력해주세요.',"]
# [None, None, None, '문의에 대한 답변드립니다.', "'문의에 대한 답변드립니다.',"]
# [None, None, None, '미평가', "tabTitleArr: const ['미평가', '평가완료'],"]
# [None, None, None, '미평가', "tabTitleArr: const ['미평가', '평가완료'],"]
# [None, None, None, '발급하기', "text: '발급하기',"]
# [None, None, None, '변경', "alertConfirm: '변경',"]
# [None, None, None, '변경', "alertConfirm: '변경',"]
# [None, None, None, '별점 관리', "text: '별점 관리',"]
# [None, None, None, '별점 관리', "text: '별점 관리',"]
# [None, None, None, '별점 평가 완료', "return '별점 평가 완료';"]
# [None, None, None, '별점관리', "title: '별점관리',"]
# [None, None, None, '별점관리', "title: '별점관리',"]
# [None, None, None, '보유 초단코인', "'보유 초단코인',"]
# [None, None, None, '보유 초단코인', "'보유 초단코인',"]
# [None, None, None, '보유 초단코인', "'보유 초단코인',"]
# [None, None, None, '복사되었습니다.', "showDefaultToast('복사되었습니다.');"]
# [None, None, None, '비노출', "'비노출',"]
# [None, None, None, '비밀글', '" 비밀글",']
# [None, None, None, '비밀글 설정', "const TitleItem(title: '비밀글 설정'),"]
# [None, None, None, '비밀번호 변경', "text: '비밀번호 변경',"]
# [None, None, None, '비밀번호를 입력해주세요.', "hintText: '비밀번호를 입력해주세요.',"]
# [None, None, None, '사용내역', "tabTitleArr: const ['사용내역', '초단코인샵'],"]
# [None, None, None, '사장님 초대하기 (10,000초코 지급)', "'사장님 초대하기 (10,000초코 지급)',"]
# [None, None, None, '사직서', "tabTitleArr: const ['계약서', '사직서'],"]
# [None, None, None, '사직서', "tabTitleArr: const ['계약서', '사직서'],"]
# [None, None, None, '사진 보관함', "child: const Text('사진 보관함'),"]
# [None, None, None, '사진 보관함', "onTap: () => getAttachedPhoto('gallery'), text: '사진 보관함'),"]
# [None, None, None, '사진 찍기', "child: const Text('사진 찍기'),"]
# [None, None, None, '사진 찍기', "onTap: () => getAttachedPhoto('camera'), text: '사진 찍기'),"]
# [None, None, None, '사진, 자격증, 포트폴리오 등으로 내 자신을 PR 해요!', ": '사진, 자격증, 포트폴리오 등으로 내 자신을 PR 해요!',"]
# [None, None, None, '사진, 자격증, 포트폴리오 등으로 내 자신을 PR 해요!', ": '사진, 자격증, 포트폴리오 등으로 내 자신을 PR 해요!',"]
# [None, None, None, '삭제', "alertConfirm: '삭제',"]
# [None, None, None, '삭제', 'text: "삭제",']
# [None, None, None, '삭제', "text: '삭제',"]
# [None, None, None, '삭제하기', "text: '삭제하기',"]
# [None, None, None, '상담 내역', "'상담 내역',"]
# [None, None, None, '상담 내용', "TitleItem(title: '상담 내용'),"]
# [None, None, None, '상담 내용', "const TitleItem(title: '상담 내용'),"]
# [None, None, None, '상담 내용', "const TitleItem(title: '상담 내용'),"]
# [None, None, None, '상담 내용을 작성해주세요.', "decoration: areaInput(hintText: '상담 내용을 작성해주세요.'),"]
# [None, None, None, '상담 답변', "'상담 답변',"]
# [None, None, None, '상담 답변', "/*const TitleItem(title: '상담 답변'),"]
# [None, None, None, '상담 삭제', "alertTitle: '상담 삭제',"]
# [None, None, None, '상담 삭제되었습니다.', "alertContent: '상담 삭제되었습니다.',"]
# [None, None, None, '상담 수정', "title: '상담 수정',"]
# [None, None, None, '상담 신청서', "title: '상담 신청서',"]
# [None, None, None, '상담 신청하기', "'상담 신청하기',"]
# [None, None, None, '상담 신청하기', "text: '상담 신청하기',"]
# [None, None, None, '상담 작성', "title: '상담 작성',"]
# [None, None, None, '상담 제목', "'상담 제목',"]
# [None, None, None, '상담 제목', "'상담 제목',"]
# [None, None, None, '상담 제목', "const TitleItem(title: '상담 제목'),"]
# [None, None, None, '상담과 무관한 내용이거나 음란 및 불법적인 내용은 통보 없이 n삭제될 수 있습니다.', "'상담과 무관한 내용이거나 음란 및 불법적인 내용은 통보 없이\\n삭제될 수 있습니다.',"]
# [None, None, None, '상담제목', '//   child: Text("상담제목"),']
# [None, None, None, '상담한 내역이 없어요', "child: CommonEmpty(text: '상담한 내역이 없어요'))),"]
# [None, None, None, '상세히 입력할수록, 제안 받을 확률이 높아져요!', ": '상세히 입력할수록, 제안 받을 확률이 높아져요!',"]
# [None, None, None, '상세히 입력할수록, 제안 받을 확률이 높아져요!', ": '상세히 입력할수록, 제안 받을 확률이 높아져요!',"]
# [None, None, None, '상세히 입력할수록, 제안 받을 확률이 높아져요!', ": '상세히 입력할수록, 제안 받을 확률이 높아져요!',"]
# [None, None, None, '상세히 입력할수록, 제안 받을 확률이 높아져요!', ": '상세히 입력할수록, 제안 받을 확률이 높아져요!',"]
# [None, None, None, '상세히 입력할수록, 제안 받을 확률이 높아져요!', "result = '상세히 입력할수록, 제안 받을 확률이 높아져요!';"]
# [None, None, None, '상세히 입력할수록, 제안 받을 확률이 높아져요!', "result = '상세히 입력할수록, 제안 받을 확률이 높아져요!';"]
# [None, None, None, '생년월일', "'생년월일',"]
# [None, None, None, '선택한 프로필을 삭제하시겠어요? n삭제한 프로필은 되돌릴 수 없어요.', "alertContent: '선택한 프로필을 삭제하시겠어요?\\n삭제한 프로필은 되돌릴 수 없어요.',"]
# [None, None, None, '설정', "tabTitleArr: ['마이페이지', '설정'],"]
# [None, None, None, '설정', "tabTitleArr: const ['마이페이지', '설정'],"]
# [None, None, None, '성명', "'성명',"]
# [None, None, None, '수정되었습니다.', "alertContent: '수정되었습니다.',"]
# [None, None, None, '수정되었습니다.', "alertContent: '수정되었습니다.',"]
# [None, None, None, '수정하기', 'text: "수정하기",']
# [None, None, None, '수정하기', "text: '수정하기',"]
# [None, None, None, '수정하기', "text: '수정하기',"]
# [None, None, None, '스크랩', "'스크랩',"]
# [None, None, None, '스크랩 공고', "tabTitleArr: const ['스크랩 공고', '최근 본 공고'],"]
# [None, None, None, '스크랩/최근 본 공고', "title: '스크랩/최근 본 공고',"]
# [None, None, None, '스크랩공고로 저장했어요!', "showDefaultToast('스크랩공고로 저장했어요!');"]
# [None, None, None, '스크랩공고에서 삭제했어요!', "showDefaultToast('스크랩공고에서 삭제했어요!');"]
# [None, None, None, '스크랩한 공고가 없습니다.', "? '스크랩한 공고가 없습니다.'"]
# [None, None, None, '신규 공고 등록', "'신규 공고 등록',"]
# [None, None, None, '신규 프로필 등록', "title: '신규 프로필 등록',"]
# [None, None, None, '신규 프로필 추가', "'신규 프로필 추가',"]
# [None, None, None, '신규 프로필 추가', "text: '신규 프로필 추가',"]
# [None, None, None, '쓰기 제한이 되었어요.', "showDefaultToast('쓰기 제한이 되었어요.');"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "alertTitle: '알림',"]
# [None, None, None, '알림', "showErrorAlert(context, '알림', '결제에 실패했습니다.');"]
# [None, None, None, '알림설정', "text: '알림설정',"]
# [None, None, None, '앱 로그아웃', "alertTitle: '앱 로그아웃',"]
# [None, None, None, '얼마 충전할까요?', "'얼마 충전할까요?',"]
# [None, None, None, '연락처', "'연락처',"]
# [None, None, None, '연락처', "'연락처',"]
# [None, None, None, '운영자에 의하여 작성이 제한된 회원입니다.', "alertContent: '운영자에 의하여 작성이 제한된 회원입니다.',"]
# [None, None, None, '운영자에 의하여 작성이 제한된 회원입니다.', "alertContent: '운영자에 의하여 작성이 제한된 회원입니다.',"]
# [None, None, None, '이메일로 전송되었어요!', "showDefaultToast('이메일로 전송되었어요!');"]
# [None, None, None, '이메일로 전송에 실패했습니다.', "showDefaultToast('이메일로 전송에 실패했습니다.');"]
# [None, None, None, '이메일로 전송에 실패했습니다. 다시 시도해 주세요.', "alertContent: '이메일로 전송에 실패했습니다. 다시 시도해 주세요.',"]
# [None, None, None, '이미 등록된 관심 기업입니다.', "showDefaultToast('이미 등록된 관심 기업입니다.');"]
# [None, None, None, '이미 등록된 관심 기업입니다.', "showDefaultToast('이미 등록된 관심 기업입니다.');"]
# [None, None, None, '이미 등록된 관심 인재입니다.', "showDefaultToast('이미 등록된 관심 인재입니다.');"]
# [None, None, None, '이미 제안하거나 지원받은 공고입니다.', "showDefaultToast('이미 제안하거나 지원받은 공고입니다.');"]
# [None, None, None, '인재 살펴 보기', "return '인재 살펴 보기';"]
# [None, None, None, '일자리 제안 받기', "'일자리 제안 받기',"]
# [None, None, None, '일자리 제안 받기', "'일자리 제안 받기',"]
# [None, None, None, '일자리 제안을 받지 않는 회원입니다.', "showDefaultToast('일자리 제안을 받지 않는 회원입니다.');"]
# [None, None, None, '일자리 제안하기', "return '일자리 제안하기';"]
# [None, None, None, '일자리 제안하기', "text: '일자리 제안하기',"]
# [None, None, None, '입사 지원', "return '입사 지원';"]
# [None, None, None, '자기소개', "title: '자기소개',"]
# [None, None, None, '자기소개', "title: '자기소개',"]
# [None, None, None, '자신만의 특별한 강점을 어필해보세요!', ": '자신만의 특별한 강점을 어필해보세요!',"]
# [None, None, None, '자신만의 특별한 강점을 어필해보세요!', ": '자신만의 특별한 강점을 어필해보세요!',"]
# [None, None, None, '작성 취소', "alertTitle: '작성 취소',"]
# [None, None, None, '작성 취소', "alertTitle: '작성 취소',"]
# [None, None, None, '작성 취소', "alertTitle: '작성 취소',"]
# [None, None, None, '작성 취소', "alertTitle: '작성 취소',"]
# [None, None, None, '작성 취소', "alertTitle: '작성 취소',"]
# [None, None, None, '작성 취소', "alertTitle: '작성 취소',"]
# [None, None, None, '작성된 계약서가 없습니다.', ": const CommonEmpty(text: '작성된 계약서가 없습니다.'),"]
# [None, None, None, '작성된 계약서가 없습니다.', "child: const CommonEmpty(text: '작성된 계약서가 없습니다.'))"]
# [None, None, None, '작성된 사직서가 없습니다.', ": const CommonEmpty(text: '작성된 사직서가 없습니다.'),"]
# [None, None, None, '작성된 사직서가 없습니다.', "child: const CommonEmpty(text: '작성된 사직서가 없습니다.'))"]
# [None, None, None, '작성하신 상담을 삭제하시겠습니까? n삭제된 내역은 복구되지 않습니다.', "alertContent: '작성하신 상담을 삭제하시겠습니까?\\n삭제된 내역은 복구되지 않습니다.',"]
# [None, None, None, '작성한 프로필을 대표 프로필로 설정하기', "'작성한 프로필을 대표 프로필로 설정하기',"]
# [None, None, None, '작성한 프로필을 대표 프로필로 설정하기', "'작성한 프로필을 대표 프로필로 설정하기',"]
# [None, None, None, '전체 업무 제안 받음', "label: '전체 업무 제안 받음',"]
# [None, None, None, '전체 업무 제안 받음', "label: '전체 업무 제안 받음',"]
# [None, None, None, '전체 업무 제안 받음', "return offerScope == 1 ? '전체 업무 제안 받음' : '희망 업무만 받음';"]
# [None, None, None, '정보수정', "TitleMenu(title: '정보수정'),"]
# [None, None, None, '제목을 입력해주세요.', "hintText: '제목을 입력해주세요.',"]
# [None, None, None, '제목을 입력해주세요.', "hintText: '제목을 입력해주세요.',"]
# [None, None, None, '제안 받지 않음', "label: '제안 받지 않음',"]
# [None, None, None, '제안 받지 않음', "label: '제안 받지 않음',"]
# [None, None, None, '제안 받지 않음', "return '제안 받지 않음';"]
# [None, None, None, '제안에 실패했습니다!', "showDefaultToast('제안에 실패했습니다!');"]
# [None, None, None, '제안에 실패했습니다!', "showDefaultToast('제안에 실패했습니다!');"]
# [None, None, None, '제안이 완료 되었어요!', "showDefaultToast('제안이 완료 되었어요!');"]
# [None, None, None, '주소', "'주소',"]
# [None, None, None, '주소', "'주소',"]
# [None, None, None, '지원', "'지원',"]
# [None, None, None, '지원일', "'지원일',"]
# [None, None, None, '차단 기업이 없습니다.', "text: activeTab == 0 ? '관심 기업이 없습니다.' : '차단 기업이 없습니다.')"]
# [None, None, None, '차단기업', "'차단기업',"]
# [None, None, None, '차단기업', "tabTitleArr: const ['관심기업', '차단기업'],"]
# [None, None, None, '차단기업에서 삭제했어요!', "showDefaultToast('차단기업에서 삭제했어요!');"]
# [None, None, None, '차단기업으로 저장했어요!', "showDefaultToast('차단기업으로 저장했어요!');"]
# [None, None, None, '차단인재', "'차단인재',"]
# [None, None, None, '차단인재', "tabTitleArr: const ['관심인재', '차단인재'],"]
# [None, None, None, '차단인재가 없습니다.', "text: activeTab == 0 ? '관심인재가 없습니다.' : '차단인재가 없습니다.')"]
# [None, None, None, '차단인재로 저장했어요!', "showDefaultToast('차단인재로 저장했어요!');"]
# [None, None, None, '차단인재에서 삭제에 실패하였습니다.', "showDefaultToast('차단인재에서 삭제에 실패하였습니다.');"]
# [None, None, None, '차단인재에서 삭제했어요!', "showDefaultToast('차단인재에서 삭제했어요!');"]
# [None, None, None, '차단인재에서 추가에 실패하였습니다.', "showDefaultToast('차단인재에서 추가에 실패하였습니다.');"]
# [None, None, None, '채용 공고 공유', "return '채용 공고 공유';"]
# [None, None, None, '채용 공고 등록', "return '채용 공고 등록';"]
# [None, None, None, '채용 공고 보기', "return '채용 공고 보기';"]
# [None, None, None, '채용 공고 스크랩', "return '채용 공고 스크랩';"]
# [None, None, None, '채용상태 변경', "text: '채용상태 변경',"]
# [None, None, None, '첨부', "title: '첨부',"]
# [None, None, None, '첨부', "title: '첨부',"]
# [None, None, None, '첨부파일', "TitleItem(title: '첨부파일'),"]
# [None, None, None, '첨부파일', "const TitleItem(title: '첨부파일'),"]
# [None, None, None, '첨부파일', "const TitleItem(title: '첨부파일'),"]
# [None, None, None, '첨부파일', "const TitleItem(title: '첨부파일'),"]
# [None, None, None, '첨부파일', "title: '첨부파일',"]
# [None, None, None, '초단알바', "subject: '초단알바');"]
# [None, None, None, '초단알바를 통해 위 기업에 입사지원 하였음을 증명합니다.', "'초단알바를 통해 위 기업에 입사지원 하였음을 증명합니다.',"]
# [None, None, None, '초단코인(초코)은 초단알바 내 결제 수단입니다.', "'초단코인(초코)은 초단알바 내 결제 수단입니다.',"]
# [None, None, None, '초단코인샵', "tabTitleArr: const ['사용내역', '초단코인샵'],"]
# [None, None, None, '초대', "return '초대';"]
# [None, None, None, '초대 성공', "return '초대 성공';"]
# [None, None, None, '초대를 받은 분이 사장님(구인)회원으로 가입한 이후 초코가 지급됩니다.', "'※ 초대를 받은 분이 사장님(구인)회원으로 가입한 이후 초코가 지급됩니다.',"]
# [None, None, None, '초코 사용 내역', "Text('초코 사용 내역',"]
# [None, None, None, '초코 사용내역이 존재하지않습니다.', "'초코 사용내역이 존재하지않습니다.'),"]
# [None, None, None, '촤근 본 공고가 없습니다.', ": '촤근 본 공고가 없습니다.')"]
# [None, None, None, '최근 본 공고', "tabTitleArr: const ['스크랩 공고', '최근 본 공고'],"]
# [None, None, None, '최근 본 인재', "'최근 본 인재',"]
# [None, None, None, '최근 본 인재', "title: '최근 본 인재',"]
# [None, None, None, '최근 본 인재가 없습니다.', "child: CommonEmpty(text: '최근 본 인재가 없습니다.'))"]
# [None, None, None, '최근 수정일', "'최근 수정일',"]
# [None, None, None, '최근 지원한 공고가 없습니다.', "text: '최근 지원한 공고가 없습니다.',"]
# [None, None, None, '최근본공고', "'최근본공고',"]
# [None, None, None, '최대 100MB까지 첨부 가능합니다.', "'최대 100MB까지 첨부 가능합니다.',"]
# [None, None, None, '최대 프로필 등록 개수를 초과했습니다.', "showDefaultToast('최대 프로필 등록 개수를 초과했습니다.');"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취소', "alertCancel: '취소',"]
# [None, None, None, '취업활동 증명서', "'취업활동 증명서',"]
# [None, None, None, '취업활동증명서 발급', "text: '취업활동증명서 발급',"]
# [None, None, None, '취업활동증명서 발급', "title: '취업활동증명서 발급',"]
# [None, None, None, '취업활동증명서 발급', "title: '취업활동증명서 발급',"]
# [None, None, None, '취업활동증명서.pdf', "return await PdfApi.saveDocumentMap(name: '취업활동증명서.pdf', pdf: pdf);"]
# [None, None, None, '친구 초대하기', "'친구 초대하기',"]
# [None, None, None, '친구 초대하기', "text: '친구 초대하기',"]
# [None, None, None, '친구 초대하기', "text: '친구 초대하기',"]
# [None, None, None, '파일 선택', "BottomSheetButton(onTap: () => getAttachedFile(), text: '파일 선택'),"]
# [None, None, None, '파일 선택', "child: const Text('파일 선택'),"]
# [None, None, None, '파일 업로드에 실패했습니다. 다시 시도해 주세요.', "alertContent: '파일 업로드에 실패했습니다. 다시 시도해 주세요.',"]
# [None, None, None, '파일 업로드에 실패했습니다. 다시 시도해 주세요.', "alertContent: '파일 업로드에 실패했습니다. 다시 시도해 주세요.',"]
# [None, None, None, '파일 업로드에 실패했습니다. 다시 시도해 주세요.', "alertContent: '파일 업로드에 실패했습니다. 다시 시도해 주세요.',"]
# [None, None, None, '파일 업로드에 실패했습니다. 다시 시도해 주세요.', "alertContent: '파일 업로드에 실패했습니다. 다시 시도해 주세요.',"]
# [None, None, None, '페이지를 이동하시겠어요? n이동 시 작성된 내용은 저장되지 않아요', "alertContent: '페이지를 이동하시겠어요?\\n이동 시 작성된 내용은 저장되지 않아요',"]
# [None, None, None, '페이지를 이동하시겠어요? n이동 시 작성된 내용은 저장되지 않아요.', "alertContent: '페이지를 이동하시겠어요?\\n이동 시 작성된 내용은 저장되지 않아요.',"]
# [None, None, None, '페이지를 이동하시겠어요? n이동 시 작성된 내용은 저장되지 않아요.', "alertContent: '페이지를 이동하시겠어요?\\n이동 시 작성된 내용은 저장되지 않아요.',"]
# [None, None, None, '페이지를 이동하시겠어요? n이동 시 작성된 내용은 저장되지 않아요.', "alertContent: '페이지를 이동하시겠어요?\\n이동 시 작성된 내용은 저장되지 않아요.',"]
# [None, None, None, '페이지를 이동하시겠어요? n이동 시 작성된 내용은 저장되지 않아요.', "alertContent: '페이지를 이동하시겠어요?\\n이동 시 작성된 내용은 저장되지 않아요.',"]
# [None, None, None, '페이지를 이동하시겠어요? n이동시 작성된 내용은 저장되지 않아요', "alertContent: '페이지를 이동하시겠어요?\\n이동시 작성된 내용은 저장되지 않아요',"]
# [None, None, None, '평가완료', "tabTitleArr: const ['미평가', '평가완료'],"]
# [None, None, None, '평가완료', "tabTitleArr: const ['미평가', '평가완료'],"]
# [None, None, None, '포인트', "'포인트',"]
# [None, None, None, '포인트', "'포인트',"]
# [None, None, None, '포지션 제안', "'포지션 제안',"]
# [None, None, None, '프로필 관리', "'프로필 관리',"]
# [None, None, None, '프로필 관리', "title: '프로필 관리',"]
# [None, None, None, '프로필 등록', "return '프로필 등록';"]
# [None, None, None, '프로필 등록에 실패하였어요. 다시 시도해주세요.', "showDefaultToast('프로필 등록에 실패하였어요. 다시 시도해주세요.');"]
# [None, None, None, '프로필 등록이 완료 되었어요!', "showDefaultToast('프로필 등록이 완료 되었어요!');"]
# [None, None, None, '프로필 등록이 완료 되었어요!', "showDefaultToast('프로필 등록이 완료 되었어요!');"]
# [None, None, None, '프로필 삭제', "alertTitle: '프로필 삭제',"]
# [None, None, None, '프로필 수정', "text: '프로필 수정'),"]
# [None, None, None, '프로필 수정', "title: '프로필 수정',"]
# [None, None, None, '프로필 수정에 실패하였습니다.', "showDefaultToast('프로필 수정에 실패하였습니다.');"]
# [None, None, None, '프로필 수정이 완료 되었어요!', "showDefaultToast('프로필 수정이 완료 되었어요!');"]
# [None, None, None, '프로필 수정이 완료 되었어요!', "showDefaultToast('프로필 수정이 완료 되었어요!');"]
# [None, None, None, '프로필 제목', "title: '프로필 제목',"]
# [None, None, None, '프로필 제목', "title: '프로필 제목',"]
# [None, None, None, '프로필은 최대 3개 등록할 수 있어요!', "'프로필은 최대 3개 등록할 수 있어요!',"]
# [None, None, None, '프리미엄 서비스', "text: '프리미엄 서비스',"]
# [None, None, None, '학력', "title: '학력',"]
# [None, None, None, '학력', "title: '학력',"]
# [None, None, None, '학력을 요구하는 업무지원에 훨씬 유리해요!', ": '학력을 요구하는 업무지원에 훨씬 유리해요!',"]
# [None, None, None, '학력을 요구하는 업무지원에 훨씬 유리해요!', ": '학력을 요구하는 업무지원에 훨씬 유리해요!',"]
# [None, None, None, '해당 계약을 한 대화방이 없습니다.', "alertContent: '해당 계약을 한 대화방이 없습니다.',"]
# [None, None, None, '해당 문의글을', '"해당 문의글을",']
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '확인', "alertConfirm: '확인',"]
# [None, None, None, '활동 포인트 관리', "text: '활동 포인트 관리',"]
# [None, None, None, '활동 포인트 관리', "text: '활동 포인트 관리',"]
# [None, None, None, '활동 포인트 관리', "title: '활동 포인트 관리',"]
# [None, None, None, '활동 포인트 내역', "TitleMenu(title: '활동 포인트 내역'),"]
# [None, None, None, '활동결과', "'활동결과',"]
# [None, None, None, '활동한 내역이 없어요.', "child: const CommonEmpty(text: '활동한 내역이 없어요.')),"]
# [None, None, None, '회원정보 수정', "text: '회원정보 수정',"]
# [None, None, None, '회원탈퇴', "text: '회원탈퇴',"]
# [None, None, None, '획득 초코', "'획득 초코',"]
# [None, None, None, '획득 초코', "'획득 초코',"]
# [None, None, None, '희망 근무 스케줄', "title: '희망 근무 스케줄',"]
# [None, None, None, '희망 근무 스케줄', "title: '희망 근무 스케줄',"]
# [None, None, None, '희망 근무 조건', "title: '희망 근무 조건',"]
# [None, None, None, '희망 근무 조건', "title: '희망 근무 조건',"]
# [None, None, None, '희망 근무 지역', "title: '희망 근무 지역',"]
# [None, None, None, '희망 근무 지역', "title: '희망 근무 지역',"]
# [None, None, None, '희망 업무만 받음', "return offerScope == 1 ? '전체 업무 제안 받음' : '희망 업무만 받음';"]
# [None, None, None, '희망 업무만 제안 받음', "label: '희망 업무만 제안 받음',"]
# [None, None, None, '희망 업무만 제안 받음', "label: '희망 업무만 제안 받음',"]
# [None, None, None, '희망 지역에서 제안을 받거나 공고를 찾아볼 수 있어요!', ": '희망 지역에서 제안을 받거나 공고를 찾아볼 수 있어요!',"]
# [None, None, None, '희망 지역에서 제안을 받거나 공고를 찾아볼 수 있어요!', ": '희망 지역에서 제안을 받거나 공고를 찾아볼 수 있어요!',"]
# [None, None, None, '희망 직종', "title: '희망 직종',"]
# [None, None, None, '희망 직종', "title: '희망 직종',"]
# [None, None, None, '희망 직종의 일자리만 제안을 받은 회원입니다.', "showDefaultToast('희망 직종의 일자리만 제안을 받은 회원입니다.');"]
# [None, None, None, '희망업무', "'희망업무',"]
# [None, None, None, '희망지역', "'희망지역',"]
# [None, None, None, '희망하는 직종을 제안 받을 수 있어요!', ": '희망하는 직종을 제안 받을 수 있어요!',"]
# [None, None, None, '희망하는 직종을 제안 받을 수 있어요!', ": '희망하는 직종을 제안 받을 수 있어요!',"]

# %%
unique_data = []
seen_values = set()
for row in pipeline.data_automatic:
    if row[4] not in seen_values:
                
        unique_data.append(row)
        
        # seen_values.add(row[4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 4
#       2 seen_values = set()
#       3 for row in pipeline.data_automatic:
# ----> 4     if row[4] not in seen_values:
#       6         unique_data.append(row)
#       7         # seen_values.add(row[4])
#
# TypeError: unhashable type: 'list'
