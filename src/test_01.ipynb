# %%
import pandas as pd

# %%
# path_file = '언어팩 수기 처리본.xlsx'
path_file = 'exam_01.xlsx'

# %%
df = pd.read_excel(path_file)

# %%
df
# Out:
#      Unnamed: 0  key  descriptions  \
# 0             0  NaN           NaN
# 1             1  NaN           NaN
# 2             2  NaN           NaN
# 3             3  NaN           NaN
# 4             4  NaN           NaN
# ..          ...  ...           ...
# 106        1673  NaN           NaN
# 107        1719  NaN           NaN
# 108        1725  NaN           NaN
# 109        1739  NaN           NaN
# 110        1745  NaN           NaN
#
#                                                     en  \
# 0    ${ConditionCareerEnum.entry.label} $minCareer ...
# 1    ${ConditionCareerEnum.experienced.label} $minC...
# 2    ${ConvertService.returnStringWithCommaFormat(j...
# 3    ${jobpostData!.workCondition.restHour}분 / ${Co...
# 4              ${jobpostData!.workCondition.restHour}분
# ..                                                 ...
# 106  ${ConvertService.returnMaskingName(matchedProf...
# 107  ${ConvertService.returnMaskingName(matchedProf...
# ...
